# %% [markdown]
# # The Python interface of exact-real
# We create a module generated by two random real numbers:

# %%
from pyexactreal import ZZModule, RealNumber
# Out:
# (Re-)building pre-compiled headers (options: -O2 -mavx); this may take a minute ...

# %%
M = ZZModule(RealNumber.random(), RealNumber.random())

print(M)
# Out:
# ℤ-Module(ℝ(0.120809…), ℝ(0.303644…))

# %% [markdown]
# Some arithmetic in this module:

# %%
x = M.gen(0);
y = M.gen(1);

print(f"{x + y} != {x * y}")
# Out:
# ℝ(0.120809…) + ℝ(0.303644…) != ℝ(0.120809…)*ℝ(0.303644…)

# %% [markdown]
# Elements can be compared:

# %%
x * y == y * x
# Out:
# True

# %%
x * y < x + y
# Out:
# True

# %%
x * y < 1
# Out:
# True
